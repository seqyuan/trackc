# %%
import trackc as tc
import pandas as pd
import os

# %%
os.chdir('/Users/yuanzan/Documents/github/seqyuan/')

# %%
df = pd.read_table('./trackc_data/tutorials/bedGraphMatrix/insulations.txt')

# %%
df['chrom'].unique()
# Out:
# array(['18', '19', 'X'], dtype=object)

# %%
regions = ['18:20000000-28000000', '19:40000000-60000000']

# %%
ten = tc.tenon(figsize=(6,1))
ten.add(pos='bottom', height=3, hspace=0.05)

tc.pl.bdgmat_track(ax=ten.axs(0), bed=df, regions=regions)
