# %% [markdown]
# # GridSpec
# Quickly layout

# %%
import sys
sys.path.append('/Users/yuanzan/Documents/github/seqyuan/trackc/src')
import trackc as tc

# %%
ten = tc.tenon(width=5, height=0.7)
ten.add(pos='bottom', height=4)
ten.add(pos='bottom', height=0.5, hspace=0.1)
ten.add(pos='bottom', height=0.7, hspace=0.1)
ten.add(pos='top', height=1, hspace=0.1)
ten.axs(0).plot([0,1])
ten.show()

# %%
ten = tc.tenon(width=5, height=0.7)
ten.add(pos='bottom', height=4)
ten.add(pos='bottom', height=0.5, hspace=0.1)
ten.add(pos='bottom', height=0.7, hspace=0.1)
ten.add(pos='top', height=1, hspace=0.1)
ten.axs(0).plot([0,1])
# tc.savefig('tenon_test.pdf')

# %%
fig, axs = tc.make_spec(figsize=(5,5), height_ratios=[1,1,1], hspace=0.2)

# %%
fig, axs = tc.make_spec(figsize=(4,5), width_ratios=[1,1,1], wspace=0.1)
axs[0].plot([1,2])
