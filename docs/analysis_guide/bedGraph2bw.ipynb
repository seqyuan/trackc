# %% [markdown]
# # bedGraph To BigWig

# %% [markdown]
# ```shell
# # 获取程序
# wget http://hgdownload.cse.ucsc.edu/admin/exe/linux.x86_64/bedGraphToBigWig
# # 加执行权限
# chmod +x bedGraphToBigWig
# # 将该文件移入PATH路径中，即可执行
# mv bedGraphToBigWig ~/bin/
# ```

# %% [markdown]
# ```shell
# ~/bin/bedGraphToBigWig insulation.bdg ~/Documents/ref/chrom_GRCh38.105.sizes insulation.bw
# ```

# %% [markdown]
# `head ~/Documents/ref/chrom_GRCh38.105.sizes`
#
# ```
# chr1	248956422
# chr2	242193529
# chr3	198295559
# chr4	190214555
# chr5	181538259
# ```
#
# `head insulation.bdg`
#
# ```
# chr1	0	10000	1
# chr1	10000	20000	0
# chr1	20000	30000	3
# chr1	30000	40000	10
# chr1	40000	50000	11
# ```

# %% [markdown]
# ### ref
# * https://open.bioqueue.org/home/knowledge/knowledgeSearchEngine/cat/39
# * https://genomebrowser.wustl.edu/goldenPath/help/bigWig.html
